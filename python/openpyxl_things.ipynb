# %%
import openpyxl

# %%
wb = openpyxl.Workbook()

# %%
wb.sheetnames
# Out:
# ['Sheet']

# %%
sheet = wb.active

# %%
sheet.title
# Out:
# 'Sheet'

# %%
sheet.title = 'ello?'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sheet.title = 'ello?'
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:93, in _WorkbookChild.title(self, value)
#      91 if m:
#      92     msg = "Invalid character {0} found in sheet title".format(m.group(0))
# ---> 93     raise ValueError(msg)
#      95 if self.title is not None and self.title != value:
#      96     value = avoid_duplicate_name(self.parent.sheetnames, value)
#
# ValueError: Invalid character ? found in sheet title

# %%
sheet.title = 'nein'

# %%
sheet.title
# Out:
# 'nein'

# %%
wb.save('dam')

# %%
wb.create_sheet()
# Out:
# <Worksheet "Sheet">

# %%
wb.sheets
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 wb.sheets
#
# AttributeError: 'Workbook' object has no attribute 'sheets'

# %%
wb.sheetnames
# Out:
# ['nein', 'Sheet']

# %%
wb.create_sheet(index = 0, title = 'be mein')
# Out:
# <Worksheet "be mein">

# %%
wb.sheetnames
# Out:
# ['be mein', 'nein', 'Sheet']
